# %%
import pandas as pd

import json      # library for working with JSON-formatted text strings
import requests  # library for accessing content from web URLs

import pprint    # library for cleanly printing Python data structures
pp = pprint.PrettyPrinter()

# %%
from twitterscraper.query import query_user_info
import pandas as pd
from multiprocessing import Pool
import time
from IPython.display import display


global twitter_user_info
twitter_user_info=[]


def get_user_info(bouldercolorado):
# Out:
#   File "<ipython-input-26-27da0f532180>", line 16
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
from twitterscraper import query_tweets

if __name__ == '__main__':
    list_of_tweets = query_tweets("Climate Change", 10)

    #print the retrieved tweets to the screen:
    for tweet in query_tweets("Climate Change", 10):
        print(tweet)
# Out:
# INFO: queries: ['Climate Change since:2006-03-21 until:2006-11-30', 'Climate Change since:2006-11-30 until:2007-08-11', 'Climate Change since:2007-08-11 until:2008-04-22', 'Climate Change since:2008-04-22 until:2009-01-01', 'Climate Change since:2009-01-01 until:2009-09-13', 'Climate Change since:2009-09-13 until:2010-05-25', 'Climate Change since:2010-05-25 until:2011-02-03', 'Climate Change since:2011-02-03 until:2011-10-16', 'Climate Change since:2011-10-16 until:2012-06-26', 'Climate Change since:2012-06-26 until:2013-03-08', 'Climate Change since:2013-03-08 until:2013-11-17', 'Climate Change since:2013-11-17 until:2014-07-29', 'Climate Change since:2014-07-29 until:2015-04-10', 'Climate Change since:2015-04-10 until:2015-12-20', 'Climate Change since:2015-12-20 until:2016-08-31', 'Climate Change since:2016-08-31 until:2017-05-12', 'Climate Change since:2017-05-12 until:2018-01-21', 'Climate Change since:2018-01-21 until:2018-10-03', 'Climate Change since:2018-10-03 until:2019-06
# ...

# %%
  #Or save the retrieved tweets to file:
    file = open(“output.txt”,”w”)
    for tweet in query_tweets("Trump OR Clinton", 10):
        file.write(tweet.encode('utf-8'))
    file.close()

# %%
pip install twitterscraper
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/89/79/a3bee8e277794f27c1cdad3a69b851d62664c419b56238435fc55b439b18/billiard-3.6.2.0-py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/54/00/74ec750cfc4e830f9d1cfdd4d559f3d2d4ba1b834b78d5266446db3fd1d6/coala_utils-0.5.1-py3-none-any.whl
# ...
# You are using pip version 9.0.3, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
from twitterscraper import query_tweets

if __name__ == '__main__':
    list_of_tweets = query_tweets("Trump OR Clinton", 10)
    #print the retrieved tweets to the screen:
    for tweet in query_tweets("Trump OR Clinton", 10):
        print(tweet)
        
  #Or save the retrieved tweets to file:
    file = open("output.txt","w")
    for tweet in query_tweets("Trump OR Clinton", 10):
        file.write(tweet.encode('utf-8'))
    file.close()
# Out:
# INFO: queries: ['climate change since:2006-03-21 until:2006-11-30', 'climate change since:2006-11-30 until:2007-08-11', 'climate change since:2007-08-11 until:2008-04-22', 'climate change since:2008-04-22 until:2009-01-01', 'climate change since:2009-01-01 until:2009-09-13', 'climate change since:2009-09-13 until:2010-05-25', 'climate change since:2010-05-25 until:2011-02-04', 'climate change since:2011-02-04 until:2011-10-16', 'climate change since:2011-10-16 until:2012-06-27', 'climate change since:2012-06-27 until:2013-03-08', 'climate change since:2013-03-08 until:2013-11-17', 'climate change since:2013-11-17 until:2014-07-30', 'climate change since:2014-07-30 until:2015-04-10', 'climate change since:2015-04-10 until:2015-12-21', 'climate change since:2015-12-21 until:2016-08-31', 'climate change since:2016-08-31 until:2017-05-13', 'climate change since:2017-05-13 until:2018-01-22', 'climate change since:2018-01-22 until:2018-10-04', 'climate change since:2018-10-04 until:2019-06
# ...

# %%
dv = query_tweets("Trump OR Clinton", 1)
dv

# %%
for tweet in query_tweets("Trump OR Clinton", 1):
    print (tweet)
# Out:
# INFO: queries: ['Trump OR Clinton since:2006-03-21 until:2006-11-30', 'Trump OR Clinton since:2006-11-30 until:2007-08-11', 'Trump OR Clinton since:2007-08-11 until:2008-04-22', 'Trump OR Clinton since:2008-04-22 until:2009-01-01', 'Trump OR Clinton since:2009-01-01 until:2009-09-13', 'Trump OR Clinton since:2009-09-13 until:2010-05-25', 'Trump OR Clinton since:2010-05-25 until:2011-02-04', 'Trump OR Clinton since:2011-02-04 until:2011-10-16', 'Trump OR Clinton since:2011-10-16 until:2012-06-27', 'Trump OR Clinton since:2012-06-27 until:2013-03-08', 'Trump OR Clinton since:2013-03-08 until:2013-11-17', 'Trump OR Clinton since:2013-11-17 until:2014-07-30', 'Trump OR Clinton since:2014-07-30 until:2015-04-10', 'Trump OR Clinton since:2015-04-10 until:2015-12-21', 'Trump OR Clinton since:2015-12-21 until:2016-08-31', 'Trump OR Clinton since:2016-08-31 until:2017-05-13', 'Trump OR Clinton since:2017-05-13 until:2018-01-22', 'Trump OR Clinton since:2018-01-22 until:2018-10-04', 'Trump OR 
# ...

# %%
pd.read_csv("blockchain_tweets.json")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-40-0d36ac95852b> in <module>
# ----> 1 pd.read_csv("blockchain_tweets.json")
#       2
#       3
#
# /srv/app/venv/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
df = pd.read_json("output.txt", encoding='utf-8')

# %%
python3 tweet_Sentiment.py 'filecoin' 'Blue' 'Trump' 'Obama'
# Out:
#   File "<ipython-input-2-ff1704438942>", line 1
#     python3 tweet_Sentiment.py 'filecoin' 'Blue' 'Trump' 'Obama'
#                           ^
# SyntaxError: invalid syntax
