# %% [markdown]
# ## Visualizing Twitter Data: Part One, Climate Change v. COVID

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import plotly.express as px
from datetime import datetime
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-d9e534b83a40> in <module>
#       4 import matplotlib as mpl
#       5 import seaborn as sns
# ----> 6 import plotly.express as px
#       7 from datetime import datetime
#
# ModuleNotFoundError: No module named 'plotly'

# %%
color= sns.palplot(sns.diverging_palette(220, 20, n=5))

# %%
load_data = pd.read_csv('Final Results.csv')
load_data_1 = pd.read_csv('Final Results ND.csv')
load_data_2 = pd.read_csv('Other Users Results.csv')

# %%
load_data['climate_emergency'] = 1
load_data_1['climate_emergency'] = 0
merged = pd.concat([load_data, load_data_1])
accounts = "Case Study Accounts.csv"
accounts = pd.read_csv(accounts)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-6a6f02a23529> in <module>
#       3 merged = pd.concat([load_data, load_data_1])
#       4 accounts = "Case Study Accounts.csv"
# ----> 5 accounts = pd.read_csv(accounts)
#
# ~\Anaconda2\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~\Anaconda2\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~\Anaconda2\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~\Anaconda2\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# ~\Anaconda2\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'Case Study Accounts.csv' does not exist: b'Case Study Accounts.csv'

# %%
df = pd.merge(merged, accounts, on='user_ID', how='left')

# %%
date = []
for x in df['time']: 
    data = datetime.strptime(x, "%Y-%m-%dT%H:%M:%S")
    date.append(data)
    
df["date"] = date   

#adds year column, makes it easier to group
df['year'] = pd.DatetimeIndex(df['date']).year

# %%
department_popularity = df.groupby("Department", as_index=False).sum()


sns.lineplot(x='year', y = "likes", hue="Department", data=df, err_style=None) #, order=None, 
              #hue_order=None, orient=None, color=None, palette=None)

# %%
sns.lineplot(x='year', y = "replies", hue="Department", data=df, err_style=None)

# %%
cc = []
keys = ["climate change", "climatechange"]

for tweet in df['tweet']:
    match = False 
    for key in keys: 
        if key.lower() in tweet:
            match = True
            break
    cc.append(1 if match else 0)
        
df['cc'] = cc

#df.loc[(df['tweet'].str.contains('climate change',case=False))]

# %%
df['cc'].sum()
# Out:
# 142

# %%
enviro = []
keys = ["climate", "climate change", "global warming","sea level rise", "greenhouse gas", "emissions", 
         "resilience", "sustainable", 
         "sustainability", "green", "carbon", "environmental justice", "pollution", "environmental"]

for tweet in df['tweet']:
    match = False 
    for key in keys: 
        if key.lower() in tweet:
            match = True
            break
    enviro.append(1 if match else 0)
        
df['enviro'] = enviro
df['enviro'].sum()
# Out:
# 1413

# %%
covid = []
keys = ["coronavirus", "COVID", "COVID-19", "SARS-CoV-2"]

for tweet in df['tweet']:
    match = False 
    for key in keys: 
        if key.lower() in tweet:
            match = True
            break
    covid.append(1 if match else 0)
        
df['covid'] = covid
df['covid'].sum()
# Out:
# 232

# %%
sns.lineplot(x='year', y = "enviro", hue="climate_emergency", data=df, palette = color, err_style=None)

# %%
sns.relplot(x="year", y="enviro", hue="climate_emergency", kind="line", data=df, err_style=None)

# %%
df['hue_test']  = "Other"
df.loc[df["enviro"] == 1, 'hue_test'] = "Environmental"
df.loc[df["covid"] == 1, 'hue_test'] = "COVID-19"
df['tweeted'] = 1
df['hue_test'].value_counts()
# Out:
# Other            72407
# Environmental     1410
# COVID-19           232
# Name: hue_test, dtype: int64

# %%
#sns.barplot(x='year', hue="hue_test", data=df)
df1 = df.loc[df['hue_test'] != "Other"]


sns.countplot(x='tweeted', hue="hue_test", data=df1)

# %%
df2 = df1.groupby("year").sum()

# %%
sns.countplot(x='year', hue="hue_test", data=df1)

# %%
sns.countplot(x='year', hue="hue_test", data=df1)

# %%
sns.countplot(x='year', y='tweeted', hue="hue_test", data=df2)
# Out:
#       Unnamed: 0  likes  replies  climate_emergency  Emergency  cc  enviro  \
# year
# 2009           2      0        0                  1        1.0   1       1
# 2013        6901      2        0                  6        6.0   6       6
# 2014        8002     17        2                 11       11.0  11      11
# 2015         949      0        0                  2        2.0   2       2
# 2016       16656     47        2                  7        7.0  17      17
# 2017        9239    406       16                  9        9.0  12      12
# 2018       44051    218        8                 35       35.0  42      42
# 2019       45320    428       28                 32       32.0  50      50
# 2020      625524   3688      366                146      146.0   1       4
#
#       covid  tweeted
# year
# 2009      0        1
# 2013      0        6
# 2014      0       11
# 2015      0        2
# 2016      0       17
# 2017      0       12
# 2018      0       42
# 2019      0       50
# 2020    232      233

# %%
continental_usa_cities = usa_cities.query('STATE not in ["HI", "AK", "PR"]')
gplt.pointplot(continental_usa_cities)

# %% [markdown]
# ## Other Users

# %%
merged = pd.concat([load_data, load_data_1, load_data_2])
merged#.groupby('username').sum()
# Out:
#      Unnamed: 0                                           username  \
# 0             0  Seattle Office of Planning & Community Develop...
# 1             1  Seattle Office of Planning & Community Develop...
# 2             3  Seattle Office of Planning & Community Develop...
# 3             4  Seattle Office of Planning & Community Develop...
# 4             5  Seattle Office of Planning & Community Develop...
# ..          ...                                                ...
# 120         735                                     Cato Institute
# 121         750                                     Cato Institute
# 122         753                                     Cato Institute
# 123         754                                     Cato Institute
# 124         762                                     Cato Institute
#
#                     time                                              tweet  \
# 0    2016-01-08T23:37:18  OPCD staff visited Lake City today to meet wit...
# 1    2016-01-08T23:37:18  OPCD staff visited Lake City today to meet wit...
# 2    2017-10-05T18:31:02  Bonus #ThrowbackThursday post: Ticket stub fro...
# 3    2017-09-29T20:17:27  Here's some photos from yesterday's successful...
# 4    2017-09-15T15:30:05  A startup aims to stop gentrification, with he...
# ..                   ...                                                ...
# 120  2019-12-01T12:51:02  The Indian Child Welfare Act strips basic cons...
# 121  2019-11-29T00:24:02  Happy Thanksgiving from the Cato Institute! We...
# 122  2019-11-28T17:29:03  Adjusting for inflation, the cost of Thanksgiv...
# 123  2019-11-28T16:29:01  Happy Thanksgiving from @CatoInstitute! There'...
# 124  2019-11-26T16:29:02  An increased supply of legal immigrant workers...
#
#      likes  replies        user_ID
# 0        1        0    SeattleOPCD
# 1        1        0    SeattleOPCD
# 2        0        0    SeattleOPCD
# 3        1        0    SeattleOPCD
# 4        1        0    SeattleOPCD
# ..     ...      ...            ...
# 120     11        0  CatoInstitute
# 121     10        2  CatoInstitute
# 122     14        3  CatoInstitute
# 123      3        2  CatoInstitute
# 124      6        1  CatoInstitute
#
# [67847 rows x 7 columns]

# %%
date = []
for x in merged['time']: 
    data = datetime.strptime(x, "%Y-%m-%dT%H:%M:%S")
    date.append(data)
    
merged["date"] = date   

#adds year column, makes it easier to group
merged ['year'] = pd.DatetimeIndex(merged['date']).year

# %%
cc = []

keys = ["climate change", "climatechange"]

for tweet in merged['tweet']:
    match = False 
    for key in keys: 
        if key.lower() in tweet:
            match = True
            break
    cc.append(1 if match else 0)
        
merged['cc'] = cc
merged
# Out:
#      Unnamed: 0                                           username  \
# 0             0  Seattle Office of Planning & Community Develop...
# 1             1  Seattle Office of Planning & Community Develop...
# 2             3  Seattle Office of Planning & Community Develop...
# 3             4  Seattle Office of Planning & Community Develop...
# 4             5  Seattle Office of Planning & Community Develop...
# ..          ...                                                ...
# 120         735                                     Cato Institute
# 121         750                                     Cato Institute
# 122         753                                     Cato Institute
# 123         754                                     Cato Institute
# 124         762                                     Cato Institute
#
#                     time                                              tweet  \
# 0    2016-01-08T23:37:18  OPCD staff visited Lake City today to meet wit...
# 1    2016-01-08T23:37:18  OPCD staff visited Lake City today to meet wit...
# 2    2017-10-05T18:31:02  Bonus #ThrowbackThursday post: Ticket stub fro...
# 3    2017-09-29T20:17:27  Here's some photos from yesterday's successful...
# 4    2017-09-15T15:30:05  A startup aims to stop gentrification, with he...
# ..                   ...                                                ...
# 120  2019-12-01T12:51:02  The Indian Child Welfare Act strips basic cons...
# 121  2019-11-29T00:24:02  Happy Thanksgiving from the Cato Institute! We...
# 122  2019-11-28T17:29:03  Adjusting for inflation, the cost of Thanksgiv...
# 123  2019-11-28T16:29:01  Happy Thanksgiving from @CatoInstitute! There'...
# 124  2019-11-26T16:29:02  An increased supply of legal immigrant workers...
#
#      likes  replies        user_ID  cc                date  year
# 0        1        0    SeattleOPCD   0 2016-01-08 23:37:18  2016
# 1        1        0    SeattleOPCD   0 2016-01-08 23:37:18  2016
# 2        0        0    SeattleOPCD   0 2017-10-05 18:31:02  2017
# 3        1        0    SeattleOPCD   0 2017-09-29 20:17:27  2017
# 4        1        0    SeattleOPCD   0 2017-09-15 15:30:05  2017
# ..     ...      ...            ...  ..                 ...   ...
# 120     11        0  CatoInstitute   0 2019-12-01 12:51:02  2019
# 121     10        2  CatoInstitute   0 2019-11-29 00:24:02  2019
# 122     14        3  CatoInstitute   0 2019-11-28 17:29:03  2019
# 123      3        2  CatoInstitute   0 2019-11-28 16:29:01  2019
# 124      6        1  CatoInstitute   0 2019-11-26 16:29:02  2019
#
# [67847 rows x 10 columns]

# %%
sns.countplot(x='likes', hue="username", data=merged)
# Out:
# /Users/martapolovin/anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning:
#
# Glyph 128655 missing from current font.
#
# /Users/martapolovin/anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning:
#
# Glyph 128652 missing from current font.
#
# /Users/martapolovin/anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning:
#
# Glyph 128654 missing from current font.
#
# /Users/martapolovin/anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning:
#
# Glyph 9972 missing from current font.
#
# /Users/martapolovin/anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning:
#
# Glyph 128656 missing from current font.
#
# /Users/martapolovin/anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning:
#
# Glyph 127961 missing from current font.
#
# /Users/martapolovin/anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning:
#
# Glyph 127960 missing from current font.
#
# /Users/martapolovin/anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning:
#
# Glyph 128154 missing from current font.
#
# /Users/martapolovin/anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning:
#
# Glyph 129532 missing from current font.
#
# /Users/martapolovin/anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning:
#
# Glyph 128080 missing from current font.
#
# /Users/martapolovin/anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning:
#
# Glyph 128175 missing from current font.
#
# /Users/martapolovin/anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning:
#
# Glyph 127758 missing from current font.
#
# /Users/martapolovin/anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning:
#
# Glyph 127794 missing from current font.
#
# /Users/martapolovin/anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning:
#
# Glyph 128655 missing from current font.
#
# /Users/martapolovin/anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning:
#
# Glyph 128652 missing from current font.
#
# /Users/martapolovin/anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning:
#
# Glyph 128654 missing from current font.
#
# /Users/martapolovin/anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning:
#
# Glyph 9972 missing from current font.
#
# /Users/martapolovin/anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning:
#
# Glyph 128656 missing from current font.
#
# /Users/martapolovin/anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning:
#
# Glyph 127961 missing from current font.
#
# /Users/martapolovin/anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning:
#
# Glyph 127960 missing from current font.
#
# /Users/martapolovin/anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning:
#
# Glyph 128154 missing from current font.
#
# /Users/martapolovin/anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning:
#
# Glyph 129532 missing from current font.
#
# /Users/martapolovin/anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning:
#
# Glyph 128080 missing from current font.
#
# /Users/martapolovin/anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning:
#
# Glyph 128175 missing from current font.
#
# /Users/martapolovin/anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning:
#
# Glyph 127758 missing from current font.
#
# /Users/martapolovin/anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning:
#
# Glyph 127794 missing from current font.
